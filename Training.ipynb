# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pandas-ta
# Out:
# Collecting pandas-ta
#   Downloading pandas_ta-0.3.14b.tar.gz (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.1/115.1 kB 1.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pandas-ta) (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas-ta) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas-ta) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas-ta) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas-ta) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->pandas-ta) (1.16.0)
# Building wheels for collected packages: pandas-ta
#   Building wheel for pandas-ta (setup.py) ... done
#   Created wheel for pandas-ta: filename=pandas_ta-0.3.14b0-py3-none-any.whl size=218907 sha256=a4d837c007bf0cc60187c7a8b9294de91dfe507cb47631f752841dc4322eb8aa
#   Stored in directory: /root/.cache/pip/wheels/69/00/ac/f7fa862c34b0e2ef320175100c233377b4c558944f12474cf0
# Successfully built pandas-ta
# Installing collected packages: pandas-ta
# Successfully installed pandas-ta-0.3.14b0

# %%
import os
import time
import numpy as np
import pandas as pd
import polars as pl
from torch.utils.data import TensorDataset, DataLoader
import torch
import torch.nn as nn
import torch.nn.functional as F
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from xgboost import XGBRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
import yfinance as yf
import pandas_ta as ta

# %%
def dataset_preprocessing(path):
    df = pd.read_csv(path).iloc[:,:-1]
    df_features = df.iloc[:,1:]
    # Features engineering
    df_features['ROC'] = ta.roc(df_features.close, length=15)
    df_features['%R'] = ta.willr(close = df_features.close, high = df_features.high, low = df_features.low, length=14)
    df_features['CCI'] = ta.cci(close = df_features.close, high = df_features.high, low = df_features.low, length=14, c=0.015)
    df_features['RSI'] = ta.rsi(close = df_features.close, high = df_features.high, low = df_features.low, length=14, scalar=100, drift=1)
    df_features['OBV'] = ta.obv(close = df_features.close, volume = df_features.volume)

    # Normalization
    df_array = df_features.values
    scaler = MinMaxScaler(feature_range=(0, 1))
    normalized_array = scaler.fit_transform(df_array)
    normalized_df = pd.DataFrame(normalized_array, columns=df_features.columns)
    normalized_df.insert(0, "time", df["time"])
    normalized_df.dropna(inplace=True)

    normalized_df.to_csv("/content/drive/MyDrive/Thesis/preprocessed_fpt_stock.csv", index=False)

path = "/content/drive/MyDrive/Thesis/fpt_stock.csv"
dataset_preprocessing(path)

# %%
class TimeSeriesDataLoader:
    def __init__(self, file_path, input_size, label_size, offset, train_size, val_size, date_column=None, target_name=None, features_type='M', batch_size=64):
        if offset < label_size:
            print(f"Offset will be change from {offset} to {label_size}")
            offset = label_size

        self.input_size = input_size
        self.label_size = label_size
        self.offset = offset
        self.train_size = train_size
        self.val_size = val_size
        self.target_name = target_name
        self.features_type = features_type
        self.batch_size = batch_size

        # Load the data
        self.df = pl.read_csv(file_path)
        if date_column is not None:
            self.df = self.df.drop(date_column)

        # Determine in_variable and out_variable based on features_type
        if features_type == 'S':
            self.in_variable = 1
            self.out_variable = 1
        elif features_type == 'M':
            self.in_variable = len(self.df.columns)
            self.out_variable = len(self.df.columns)
        elif features_type == 'MS':
            self.in_variable = len(self.df.columns)
            self.out_variable = 1
        else:
            raise ValueError("Invalid features_type. Choose from 'S' for Univariate-to-Univariate, 'M' for Multivariate-to-Multivariate, 'MS' for Multivariate-to-Univariate.")

        # Preprocess the data
        self.X_train, self.y_train = self.__create_dataset(0, int(train_size * len(self.df)))
        print(f'{self.X_train.shape = }')
        print(f'{self.y_train.shape = }')
        self.X_val, self.y_val = self.__create_dataset(int(train_size * len(self.df)), int((train_size + val_size) * len(self.df)))
        print(f'{self.X_val.shape = }')
        print(f'{self.y_val.shape = }')
        self.X_test, self.y_test = self.__create_dataset(int((train_size + val_size) * len(self.df)), None)
        print(f'{self.X_test.shape = }')
        print(f'{self.y_test.shape = }')

        # Convert to PyTorch DataLoaders
        self.train_loader = self.__create_dataloader(self.X_train, self.y_train)
        self.val_loader = self.__create_dataloader(self.X_val, self.y_val)
        self.test_loader = self.__create_dataloader(self.X_test, self.y_test)

    def __create_dataset(self, start_idx, end_idx):
        if end_idx is None:
            end_idx = len(self.df) - self.label_size - self.offset

        start_idx += self.input_size + self.offset

        features = []
        labels = []

        for idx in range(start_idx, end_idx):
            feature_start_idx = idx - self.input_size - self.offset
            feature_end_idx = feature_start_idx + self.input_size

            label_start_idx = idx - 1
            label_end_idx = label_start_idx + self.label_size

            if self.features_type == 'S':
                feature = self.df.select(self.target_name)[feature_start_idx:feature_end_idx]
                label = self.df.select(self.target_name)[label_start_idx:label_end_idx]
            elif self.features_type == 'M':
                feature = self.df[feature_start_idx:feature_end_idx]
                label = self.df[label_start_idx:label_end_idx]
            elif self.features_type == 'MS':
                feature = self.df[feature_start_idx:feature_end_idx]
                label = self.df.select(self.target_name)[label_start_idx:label_end_idx]
            else:
                raise ValueError("Invalid features_type. Choose from 'S', 'M', 'MS'.")

            features.append(feature.to_numpy())
            labels.append(label.to_numpy())
            self.out_features = label.columns
            self.in_features = label.columns

        return np.array(features), np.array(labels)

    def __create_dataloader(self, X, y):
        X_tensor = torch.tensor(X, dtype=torch.float32)
        y_tensor = torch.tensor(y, dtype=torch.float32)
        dataset = TensorDataset(X_tensor, y_tensor)
        return DataLoader(dataset, batch_size=self.batch_size, shuffle=True)

# %%
import torch
import torch.nn as nn

class ModelManager(TimeSeriesDataLoader):
    def __init__(self, model, train_loader, val_loader=None, lr=0.001, patience=100):
        self.model = model
        self.train_loader = train_loader
        self.val_loader = val_loader
        self.patience = patience
        self.best_loss = float('inf')
        self.counter = 0
        self.criterion = nn.L1Loss()
        self.optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    def train(self, num_epochs, save_dir='.'):
        os.makedirs(save_dir, exist_ok=True)
        save_path = os.path.join(save_dir, f'best-{self.model.__class__.__name__}.pth')
        for epoch in range(num_epochs):
            start_time = time.time()
            self.model.train()  # Set the model to training mode
            total_train_loss = 0

            for inputs, targets in self.train_loader:
                # Forward pass
                outputs = self.model(inputs)
                loss = self.criterion(outputs, targets)
                total_train_loss += loss.item()

                # Backward pass and optimization
                self.optimizer.zero_grad()
                loss.backward()
                self.optimizer.step()

            avg_train_loss = total_train_loss / len(self.train_loader)

            # Validate the model
            val_loss = self.evaluate(loader=self.val_loader)

            # Check for early stopping
            if self.early_stopping(val_loss, save_path):
                print(f"Early stopping at epoch {epoch + 1}")
                return

            print(f'Epoch [{epoch + 1}/{num_epochs}], '
                  f'time: {int(time.time() - start_time)}s, '
                  f'loss: {avg_train_loss:.4f}, '
                  f'val_loss: {val_loss:.4f}')

        self.load_model(save_path)

    def evaluate(self, loader):
        self.model.eval()  # Set the model to evaluation mode
        total_loss = 0

        with torch.no_grad():
            for inputs, targets in loader:
                outputs = self.model(inputs)
                loss = self.criterion(outputs, targets)
                total_loss += loss.item()

        avg_loss = total_loss / len(loader)
        return avg_loss

    def early_stopping(self, val_loss, save_path):
        if val_loss < self.best_loss:
            self.best_loss = val_loss
            self.counter = 0
            self.save_model(save_path)
        else:
            self.counter += 1
        return self.counter >= self.patience

    def save_model(self, save_path):
        torch.save(self.model.state_dict(), save_path)
        print(f'Model saved to {save_path}')

    def load_model(self, load_path):
        self.model.load_state_dict(torch.load(load_path))
        print(f'Model loaded from {load_path}')

    def predict(self, input_data):
        self.model.eval()  # Set the model to evaluation mode

        if isinstance(input_data, DataLoader):
            # If input_data is a DataLoader, iterate through batches and concatenate predictions
            predictions = []
            with torch.no_grad():
                for inputs, _ in input_data:
                    outputs = self.model(inputs)
                    predictions.append(outputs)
            predictions = torch.cat(predictions, dim=0)
        else:
            # Assume input_data is a single input tensor
            with torch.no_grad():
                predictions = self.model(input_data).unsqueeze(0)

        return predictions

    def plot(self, y, yhat, feature_names=None, save_dir='.', save_plots=True, num_elements=None):
        if feature_names is None:
            feature_names = [f'Feature {i + 1}' for i in range(y.shape[2])]

        if num_elements is not None:
            y = y[:num_elements]
            yhat = yhat[:num_elements]

        for feature_index, feature_name in enumerate(feature_names):
            plt.figure(figsize=(10, 5))

            plt.plot(y[:, :, feature_index].flatten(), label='y', linestyle='-')
            plt.plot(yhat[:, :, feature_index].flatten(), label='y_hat', linestyle='--')

            plt.title(feature_name)
            plt.xlabel('Time Step')
            plt.ylabel('Values')
            plt.legend()

            if save_plots:
                # Create the save directory if it doesn't exist
                os.makedirs(os.path.join(save_dir, self.model.__class__.__name__), exist_ok=True)

                # Save the plot
                save_path = os.path.join(save_dir, self.model.__class__.__name__, f'{feature_name}.png')
                plt.savefig(save_path)

            plt.show()
            plt.close()  # Close the plot to avoid overlapping in saved images

class MachineLearningModelManager(ModelManager):
    def __init__(self, model, xtrain, ytrain, xval, yval):
        self.model = model
        self.xtrain = xtrain
        self.ytrain = ytrain
        self.xval = xval
        self.yval = yval

    def preprocessing(self, x):
        return x.reshape(x.shape[0], -1)

    def save_model(self, save_path):
        import pickle
        with open(save_path, 'wb') as model_file:
            pickle.dump(self.model, model_file)
        print(f'Model saved to {save_path}')

    def train(self, save_dir='.'):
        self.model.fit(self.preprocessing(self.xtrain),
                       self.preprocessing(self.ytrain),
                       eval_set=[(self.preprocessing(self.xval), self.preprocessing(self.yval))])
        save_path = os.path.join(save_dir, f'best-{self.model.__class__.__name__}.pkl')
        self.save_model(save_path=save_path)

    def predict(self, x):
        return self.model.predict(self.preprocessing(x))

    def evaluate(self, x, y):
        from sklearn.metrics import mean_squared_error
        #from sklearn.metrics import mean_absolute_error

        # print(self.preprocessing(y).shape)
        # print(self.predict(self.preprocessing(x)).shape)
        return mean_squared_error(self.preprocessing(y), self.predict(self.preprocessing(x)))

    def plot(self, y, yhat, feature_names=None, save_dir='.', save_plots=True, num_elements=None):
        yhat = yhat.reshape(y.shape[0], y.shape[1], -1)
        super().plot(y, yhat, feature_names=feature_names, save_dir=save_dir, save_plots=save_plots, num_elements=num_elements)

# %%
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers, ahead):
        super(RNN, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.ahead = ahead
        self.output_size = output_size

        # RNN Layer - can be replaced with nn.LSTM or nn.GRU
        self.rnn = nn.RNN(input_size, hidden_size, num_layers, batch_first=True)

        # Output layer
        self.fc = nn.Linear(hidden_size, output_size * ahead)

    def forward(self, x):
        # Initialize hidden state
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)

        # Forward propagate RNN
        out, _ = self.rnn(x, h0)

        # Get the last time step's output for each sequence
        out = out[:, -1, :]

        # Pass through the linear layer and reshape
        out = self.fc(out).view(-1, self.ahead, self.output_size)
        return out

# %% [markdown]
# ### Configs

# %%
input_size = 30
label_size = 1
offset = 1
train_size = 0.8
val_size = 0.1
num_epochs = 1_000
patience = 100
learning_rate = 0.001
hidden_size = 64
num_layers = 2
ele = None
target_name = 'close'
date_column = 'time'
file_path = '/content/drive/MyDrive/Thesis/preprocessed_fpt_stock.csv'
plot_dir = 'plots'
weight_dir = 'weights'
results = []

# %%
# features_type='S'
# sub_dir = 'uni2uni'
features_type='MS'
sub_dir = 'multi2multi'
os.makedirs(os.path.join(weight_dir, sub_dir), exist_ok=True)
multi2multi_loader = TimeSeriesDataLoader(file_path,
                                          input_size=input_size,
                                          label_size=label_size,
                                          offset=offset,
                                          train_size=train_size,
                                          val_size=val_size,
                                          target_name=target_name,
                                          features_type=features_type,
                                          date_column=date_column)
# Out:
# self.X_train.shape = (2305, 30, 10)
# self.y_train.shape = (2305, 1, 1)
# self.X_val.shape = (261, 30, 10)
# self.y_val.shape = (261, 1, 1)
# self.X_test.shape = (259, 30, 10)
# self.y_test.shape = (259, 1, 1)

# %%
RNN_multi2multi = RNN(input_size=multi2multi_loader.in_variable,
                      hidden_size=hidden_size,
                      output_size=multi2multi_loader.out_variable,
                      ahead=label_size,
                      num_layers=num_layers)
RNN_multi2multi_manager = ModelManager(model=RNN_multi2multi,
                                       train_loader=multi2multi_loader.train_loader,
                                       val_loader=multi2multi_loader.val_loader,
                                       lr=learning_rate,
                                       patience=patience
                                       )
RNN_multi2multi_manager.train(num_epochs=num_epochs,
                              save_dir=os.path.join(weight_dir, sub_dir))
results.append({
    "Name": RNN_multi2multi_manager.model.__class__.__name__,
    "Type": sub_dir,
    "MSE": RNN_multi2multi_manager.evaluate(loader=multi2multi_loader.test_loader)
})
results[-1]
# Out:
# Model saved to weights/multi2multi/best-RNN.pth
# Epoch [1/1000], time: 1s, loss: 0.0523, val_loss: 0.1977
# Model saved to weights/multi2multi/best-RNN.pth
# Epoch [2/1000], time: 1s, loss: 0.0180, val_loss: 0.0776
# Epoch [3/1000], time: 0s, loss: 0.0109, val_loss: 0.1302
# Epoch [4/1000], time: 0s, loss: 0.0095, val_loss: 0.0932
# Model saved to weights/multi2multi/best-RNN.pth
# Epoch [5/1000], time: 0s, loss: 0.0068, val_loss: 0.0512
# Model saved to weights/multi2multi/best-RNN.pth
# Epoch [6/1000], time: 0s, loss: 0.0068, val_loss: 0.0317
# Epoch [7/1000], time: 0s, loss: 0.0088, val_loss: 0.0512
# Model saved to weights/multi2multi/best-RNN.pth
# Epoch [8/1000], time: 0s, loss: 0.0051, val_loss: 0.0148
# Epoch [9/1000], time: 0s, loss: 0.0056, val_loss: 0.0177
# Epoch [10/1000], time: 1s, loss: 0.0076, val_loss: 0.0506
# Epoch [11/1000], time: 0s, loss: 0.0094, val_loss: 0.0439
# Epoch [12/1000], time: 0s, loss: 0.0062, val_loss: 0.0451
# Epoch [13/1000], time: 0s, loss: 0.0110, val_loss: 0.0387
# Model saved to weights/multi2multi/best-RNN.pth
# Epoch [14/1000], time: 1s, loss: 0.0042, val_loss: 0.0113
# Epoch [15/1000], time: 1s, loss: 0.0047, val_loss: 0.0132
# Epoch [16/1000], time: 1s, loss: 0.0075, val_loss: 0.0231
# Epoch [17/1000], time: 1s, loss: 0.0046, val_loss: 0.0177
# Epoch [18/1000], time: 0s, loss: 0.0033, val_loss: 0.0369
# Epoch [19/1000], time: 0s, loss: 0.0050, val_loss: 0.0134
# Epoch [20/1000], time: 1s, loss: 0.0041, val_loss: 0.0119
# Epoch [21/1000], time: 1s, loss: 0.0050, val_loss: 0.0266
# Epoch [22/1000], time: 1s, loss: 0.0041, val_loss: 0.0135
# Epoch [23/1000], time: 1s, loss: 0.0037, val_loss: 0.0127
# Model saved to weights/multi2multi/best-RNN.pth
# Epoch [24/1000], time: 1s, loss: 0.0074, val_loss: 0.0106
# Epoch [25/1000], time: 0s, loss: 0.0048, val_loss: 0.0144
# Epoch [26/1000], time: 1s, loss: 0.0043, val_loss: 0.0396
# Epoch [27/1000], time: 1s, loss: 0.0080, val_loss: 0.0171
# Model saved to weights/multi2multi/best-RNN.pth
# Epoch [28/1000], time: 1s, loss: 0.0037, val_loss: 0.0106
# Epoch [29/1000], time: 1s, loss: 0.0038, val_loss: 0.0342
# Epoch [30/1000], time: 0s, loss: 0.0053, val_loss: 0.0335
# Epoch [31/1000], time: 0s, loss: 0.0062, val_loss: 0.0247
# Epoch [32/1000], time: 0s, loss: 0.0040, val_loss: 0.0168
# Epoch [33/1000], time: 0s, loss: 0.0054, val_loss: 0.0180
# Epoch [34/1000], time: 0s, loss: 0.0033, val_loss: 0.0108
# Epoch [35/1000], time: 0s, loss: 0.0038, val_loss: 0.0249
# Epoch [36/1000], time: 0s, loss: 0.0048, val_loss: 0.0116
# Epoch [37/1000], time: 0s, loss: 0.0041, val_loss: 0.0523
# Epoch [38/1000], time: 0s, loss: 0.0100, val_loss: 0.0185
# Epoch [39/1000], time: 0s, loss: 0.0042, val_loss: 0.0316
# Epoch [40/1000], time: 0s, loss: 0.0045, val_loss: 0.0107
# Epoch [41/1000], time: 0s, loss: 0.0030, val_loss: 0.0170
# Epoch [42/1000], time: 0s, loss: 0.0043, val_loss: 0.0272
# Epoch [43/1000], time: 0s, loss: 0.0054, val_loss: 0.0142
# Epoch [44/1000], time: 0s, loss: 0.0045, val_loss: 0.0675
# Epoch [45/1000], time: 0s, loss: 0.0107, val_loss: 0.0226
# Epoch [46/1000], time: 0s, loss: 0.0031, val_loss: 0.0500
# Epoch [47/1000], time: 0s, loss: 0.0053, val_loss: 0.0173
# Epoch [48/1000], time: 0s, loss: 0.0032, val_loss: 0.0108
# Epoch [49/1000], time: 0s, loss: 0.0038, val_loss: 0.0285
# Epoch [50/1000], time: 0s, loss: 0.0041, val_loss: 0.0281
# Epoch [51/1000], time: 0s, loss: 0.0036, val_loss: 0.0202
# Epoch [52/1000], time: 0s, loss: 0.0031, val_loss: 0.0147
# Epoch [53/1000], time: 0s, loss: 0.0033, val_loss: 0.0293
# Epoch [54/1000], time: 0s, loss: 0.0038, val_loss: 0.0133
# Epoch [55/1000], time: 0s, loss: 0.0038, val_loss: 0.0180
# Epoch [56/1000], time: 0s, loss: 0.0032, val_loss: 0.0158
# Epoch [57/1000], time: 0s, loss: 0.0041, val_loss: 0.0121
# Model saved to weights/multi2multi/best-RNN.pth
# Epoch [58/1000], time: 0s, loss: 0.0036, val_loss: 0.0102
# Epoch [59/1000], time: 0s, loss: 0.0030, val_loss: 0.0113
# Epoch [60/1000], time: 0s, loss: 0.0029, val_loss: 0.0175
# Epoch [61/1000], time: 0s, loss: 0.0030, val_loss: 0.0218
# Epoch [62/1000], time: 0s, loss: 0.0034, val_loss: 0.0148
# Epoch [63/1000], time: 0s, loss: 0.0035, val_loss: 0.0230
# Model saved to weights/multi2multi/best-RNN.pth
# Epoch [64/1000], time: 0s, loss: 0.0041, val_loss: 0.0101
# Epoch [65/1000], time: 0s, loss: 0.0040, val_loss: 0.0138
# Epoch [66/1000], time: 0s, loss: 0.0032, val_loss: 0.0196
# Epoch [67/1000], time: 0s, loss: 0.0034, val_loss: 0.0356
# Epoch [68/1000], time: 0s, loss: 0.0058, val_loss: 0.0119
# Epoch [69/1000], time: 0s, loss: 0.0029, val_loss: 0.0101
# Epoch [70/1000], time: 0s, loss: 0.0040, val_loss: 0.0155
# Epoch [71/1000], time: 0s, loss: 0.0040, val_loss: 0.0120
# Epoch [72/1000], time: 0s, loss: 0.0033, val_loss: 0.0142
# Epoch [73/1000], time: 0s, loss: 0.0042, val_loss: 0.0195
# Epoch [74/1000], time: 0s, loss: 0.0034, val_loss: 0.0143
# Epoch [75/1000], time: 0s, loss: 0.0033, val_loss: 0.0266
# Epoch [76/1000], time: 0s, loss: 0.0051, val_loss: 0.0109
# Epoch [77/1000], time: 0s, loss: 0.0053, val_loss: 0.0125
# Epoch [78/1000], time: 0s, loss: 0.0032, val_loss: 0.0115
# Epoch [79/1000], time: 0s, loss: 0.0033, val_loss: 0.0113
# Epoch [80/1000], time: 0s, loss: 0.0040, val_loss: 0.0115
# Model saved to weights/multi2multi/best-RNN.pth
# Epoch [81/1000], time: 0s, loss: 0.0029, val_loss: 0.0095
# Epoch [82/1000], time: 0s, loss: 0.0040, val_loss: 0.0104
# Epoch [83/1000], time: 0s, loss: 0.0030, val_loss: 0.0276
# Epoch [84/1000], time: 0s, loss: 0.0052, val_loss: 0.0293
# Epoch [85/1000], time: 0s, loss: 0.0043, val_loss: 0.0495
# Epoch [86/1000], time: 0s, loss: 0.0069, val_loss: 0.0102
# Epoch [87/1000], time: 0s, loss: 0.0043, val_loss: 0.0159
# Epoch [88/1000], time: 0s, loss: 0.0027, val_loss: 0.0160
# Epoch [89/1000], time: 0s, loss: 0.0028, val_loss: 0.0110
# Epoch [90/1000], time: 0s, loss: 0.0042, val_loss: 0.0253
# Epoch [91/1000], time: 0s, loss: 0.0055, val_loss: 0.0105
# Epoch [92/1000], time: 0s, loss: 0.0038, val_loss: 0.0499
# Epoch [93/1000], time: 0s, loss: 0.0075, val_loss: 0.0139
# Epoch [94/1000], time: 0s, loss: 0.0028, val_loss: 0.0118
# Epoch [95/1000], time: 0s, loss: 0.0031, val_loss: 0.0208
# Epoch [96/1000], time: 0s, loss: 0.0044, val_loss: 0.0181
# Epoch [97/1000], time: 0s, loss: 0.0030, val_loss: 0.0242
# Epoch [98/1000], time: 0s, loss: 0.0045, val_loss: 0.0108
# Epoch [99/1000], time: 0s, loss: 0.0029, val_loss: 0.0113
# Epoch [100/1000], time: 0s, loss: 0.0030, val_loss: 0.0164
# Epoch [101/1000], time: 0s, loss: 0.0042, val_loss: 0.0249
# Epoch [102/1000], time: 0s, loss: 0.0033, val_loss: 0.0156
# Epoch [103/1000], time: 0s, loss: 0.0036, val_loss: 0.0345
# Epoch [104/1000], time: 0s, loss: 0.0052, val_loss: 0.0356
# Epoch [105/1000], time: 0s, loss: 0.0044, val_loss: 0.0155
# Epoch [106/1000], time: 0s, loss: 0.0032, val_loss: 0.0347
# Model saved to weights/multi2multi/best-RNN.pth
# Epoch [107/1000], time: 0s, loss: 0.0042, val_loss: 0.0089
# Epoch [108/1000], time: 0s, loss: 0.0031, val_loss: 0.0154
# Epoch [109/1000], time: 0s, loss: 0.0028, val_loss: 0.0185
# Epoch [110/1000], time: 0s, loss: 0.0040, val_loss: 0.0221
# Epoch [111/1000], time: 0s, loss: 0.0042, val_loss: 0.0207
# Epoch [112/1000], time: 0s, loss: 0.0036, val_loss: 0.0135
# Epoch [113/1000], time: 0s, loss: 0.0038, val_loss: 0.0226
# Epoch [114/1000], time: 0s, loss: 0.0033, val_loss: 0.0126
# Epoch [115/1000], time: 0s, loss: 0.0033, val_loss: 0.0151
# Epoch [116/1000], time: 0s, loss: 0.0039, val_loss: 0.0126
# Epoch [117/1000], time: 0s, loss: 0.0030, val_loss: 0.0247
# Epoch [118/1000], time: 0s, loss: 0.0034, val_loss: 0.0098
# Epoch [119/1000], time: 0s, loss: 0.0032, val_loss: 0.0190
# Epoch [120/1000], time: 0s, loss: 0.0031, val_loss: 0.0097
# Epoch [121/1000], time: 0s, loss: 0.0049, val_loss: 0.0111
# Epoch [122/1000], time: 0s, loss: 0.0039, val_loss: 0.0099
# Epoch [123/1000], time: 0s, loss: 0.0031, val_loss: 0.0187
# Epoch [124/1000], time: 0s, loss: 0.0034, val_loss: 0.0104
# Epoch [125/1000], time: 0s, loss: 0.0033, val_loss: 0.0141
# Epoch [126/1000], time: 0s, loss: 0.0030, val_loss: 0.0116
# Epoch [127/1000], time: 0s, loss: 0.0043, val_loss: 0.0135
# Epoch [128/1000], time: 0s, loss: 0.0030, val_loss: 0.0198
# Epoch [129/1000], time: 0s, loss: 0.0045, val_loss: 0.0106
# Epoch [130/1000], time: 0s, loss: 0.0031, val_loss: 0.0124
# Epoch [131/1000], time: 0s, loss: 0.0035, val_loss: 0.0106
# Epoch [132/1000], time: 0s, loss: 0.0031, val_loss: 0.0152
# Epoch [133/1000], time: 0s, loss: 0.0038, val_loss: 0.0304
# Epoch [134/1000], time: 0s, loss: 0.0047, val_loss: 0.0188
# Epoch [135/1000], time: 0s, loss: 0.0033, val_loss: 0.0138
# Epoch [136/1000], time: 0s, loss: 0.0038, val_loss: 0.0127
# Epoch [137/1000], time: 0s, loss: 0.0033, val_loss: 0.0102
# Epoch [138/1000], time: 0s, loss: 0.0030, val_loss: 0.0141
# Epoch [139/1000], time: 0s, loss: 0.0030, val_loss: 0.0119
# Epoch [140/1000], time: 0s, loss: 0.0027, val_loss: 0.0115
# Epoch [141/1000], time: 0s, loss: 0.0032, val_loss: 0.0096
# Epoch [142/1000], time: 0s, loss: 0.0028, val_loss: 0.0226
# Epoch [143/1000], time: 0s, loss: 0.0041, val_loss: 0.0110
# Epoch [144/1000], time: 0s, loss: 0.0031, val_loss: 0.0094
# Epoch [145/1000], time: 0s, loss: 0.0032, val_loss: 0.0106
# Epoch [146/1000], time: 0s, loss: 0.0029, val_loss: 0.0356
# Epoch [147/1000], time: 0s, loss: 0.0064, val_loss: 0.0156
# Epoch [148/1000], time: 0s, loss: 0.0027, val_loss: 0.0130
# Epoch [149/1000], time: 0s, loss: 0.0039, val_loss: 0.0209
# Epoch [150/1000], time: 0s, loss: 0.0035, val_loss: 0.0265
# Epoch [151/1000], time: 0s, loss: 0.0041, val_loss: 0.0130
# Epoch [152/1000], time: 0s, loss: 0.0028, val_loss: 0.0144
# Epoch [153/1000], time: 0s, loss: 0.0040, val_loss: 0.0106
# Epoch [154/1000], time: 0s, loss: 0.0026, val_loss: 0.0125
# Epoch [155/1000], time: 0s, loss: 0.0033, val_loss: 0.0135
# Epoch [156/1000], time: 0s, loss: 0.0037, val_loss: 0.0243
# Epoch [157/1000], time: 0s, loss: 0.0032, val_loss: 0.0294
# Epoch [158/1000], time: 0s, loss: 0.0047, val_loss: 0.0313
# Epoch [159/1000], time: 0s, loss: 0.0059, val_loss: 0.0122
# Epoch [160/1000], time: 0s, loss: 0.0038, val_loss: 0.0107
# Epoch [161/1000], time: 0s, loss: 0.0029, val_loss: 0.0166
# Epoch [162/1000], time: 0s, loss: 0.0035, val_loss: 0.0142
# Epoch [163/1000], time: 0s, loss: 0.0042, val_loss: 0.0153
# Epoch [164/1000], time: 0s, loss: 0.0040, val_loss: 0.0185
# Epoch [165/1000], time: 0s, loss: 0.0031, val_loss: 0.0129
# Epoch [166/1000], time: 0s, loss: 0.0035, val_loss: 0.0226
# Epoch [167/1000], time: 0s, loss: 0.0032, val_loss: 0.0138
# Epoch [168/1000], time: 0s, loss: 0.0033, val_loss: 0.0124
# Epoch [169/1000], time: 0s, loss: 0.0025, val_loss: 0.0129
# Epoch [170/1000], time: 0s, loss: 0.0031, val_loss: 0.0189
# Epoch [171/1000], time: 0s, loss: 0.0033, val_loss: 0.0116
# Epoch [172/1000], time: 0s, loss: 0.0029, val_loss: 0.0132
# Epoch [173/1000], time: 0s, loss: 0.0032, val_loss: 0.0107
# Epoch [174/1000], time: 0s, loss: 0.0030, val_loss: 0.0131
# Epoch [175/1000], time: 0s, loss: 0.0030, val_loss: 0.0207
# Epoch [176/1000], time: 0s, loss: 0.0033, val_loss: 0.0243
# Epoch [177/1000], time: 0s, loss: 0.0042, val_loss: 0.0104
# Epoch [178/1000], time: 0s, loss: 0.0030, val_loss: 0.0110
# Epoch [179/1000], time: 0s, loss: 0.0034, val_loss: 0.0163
# Epoch [180/1000], time: 0s, loss: 0.0029, val_loss: 0.0150
# Epoch [181/1000], time: 0s, loss: 0.0034, val_loss: 0.0225
# Epoch [182/1000], time: 0s, loss: 0.0043, val_loss: 0.0185
# Epoch [183/1000], time: 0s, loss: 0.0056, val_loss: 0.0315
# Epoch [184/1000], time: 0s, loss: 0.0053, val_loss: 0.0103
# Epoch [185/1000], time: 0s, loss: 0.0028, val_loss: 0.0103
# Epoch [186/1000], time: 0s, loss: 0.0033, val_loss: 0.0300
# Epoch [187/1000], time: 0s, loss: 0.0041, val_loss: 0.0236
# Epoch [188/1000], time: 0s, loss: 0.0038, val_loss: 0.0123
# Epoch [189/1000], time: 0s, loss: 0.0028, val_loss: 0.0164
# Epoch [190/1000], time: 0s, loss: 0.0032, val_loss: 0.0142
# Epoch [191/1000], time: 0s, loss: 0.0029, val_loss: 0.0339
# Epoch [192/1000], time: 0s, loss: 0.0032, val_loss: 0.0155
# Epoch [193/1000], time: 0s, loss: 0.0032, val_loss: 0.0323
# Epoch [194/1000], time: 0s, loss: 0.0045, val_loss: 0.0110
# Epoch [195/1000], time: 0s, loss: 0.0027, val_loss: 0.0174
# Epoch [196/1000], time: 0s, loss: 0.0041, val_loss: 0.0202
# Epoch [197/1000], time: 0s, loss: 0.0044, val_loss: 0.0104
# Epoch [198/1000], time: 0s, loss: 0.0027, val_loss: 0.0117
# Epoch [199/1000], time: 0s, loss: 0.0034, val_loss: 0.0213
# Epoch [200/1000], time: 0s, loss: 0.0029, val_loss: 0.0155
# Epoch [201/1000], time: 0s, loss: 0.0038, val_loss: 0.0180
# Epoch [202/1000], time: 0s, loss: 0.0032, val_loss: 0.0132
# Epoch [203/1000], time: 0s, loss: 0.0032, val_loss: 0.0109
# Epoch [204/1000], time: 0s, loss: 0.0038, val_loss: 0.0112
# Epoch [205/1000], time: 0s, loss: 0.0028, val_loss: 0.0113
# Epoch [206/1000], time: 0s, loss: 0.0025, val_loss: 0.0099
# Early stopping at epoch 207
# {'Name': 'RNN', 'Type': 'multi2multi', 'MSE': 0.02300051338970661}

# %%
RNN_multi2multi_manager.plot(y=multi2multi_loader.y_test,
                             yhat=RNN_multi2multi_manager.predict(multi2multi_loader.test_loader),
                             feature_names=multi2multi_loader.out_features,
                             save_dir=os.path.join(plot_dir, sub_dir),
                             save_plots=True,
                             num_elements=ele)

# %%
class MLP(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, ahead):
        super(MLP, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size, output_size * ahead)  # Adjust for output sequence length
        self.ahead = ahead
        self.output_size = output_size

    def forward(self, x):
        # Flatten the input
        x = x.view(x.size(0), -1)  # Reshape from [batch, lag, features] to [batch, lag * features]
        x = self.fc1(x)
        x = self.relu(x)

        x = self.fc2(x)
        return x.view(-1, self.ahead, self.output_size)  # Reshape to [batch, ahead, features]

# %%
MLP_multi2multi = MLP(input_size=multi2multi_loader.in_variable*input_size,
                      hidden_size=hidden_size,
                      output_size=multi2multi_loader.out_variable,
                      ahead=label_size)
MLP_multi2multi_manager = ModelManager(model=MLP_multi2multi,
                                       train_loader=multi2multi_loader.train_loader,
                                       val_loader=multi2multi_loader.val_loader,
                                       lr=learning_rate,
                                       patience=patience)
MLP_multi2multi_manager.train(num_epochs=num_epochs,
                              save_dir=os.path.join(weight_dir, sub_dir))
results.append({
    "Name": MLP_multi2multi_manager.model.__class__.__name__,
    "Type": sub_dir,
    "MAE": MLP_multi2multi_manager.evaluate(loader=multi2multi_loader.test_loader)
})
results[-1]
# Out:
# Model saved to weights/multi2multi/best-MLP.pth
# Epoch [1/1000], time: 0s, loss: 0.0365, val_loss: 0.0830
# Model saved to weights/multi2multi/best-MLP.pth
# Epoch [2/1000], time: 0s, loss: 0.0153, val_loss: 0.0825
# Model saved to weights/multi2multi/best-MLP.pth
# Epoch [3/1000], time: 0s, loss: 0.0185, val_loss: 0.0219
# Epoch [4/1000], time: 0s, loss: 0.0084, val_loss: 0.0419
# Epoch [5/1000], time: 0s, loss: 0.0093, val_loss: 0.0449
# Epoch [6/1000], time: 0s, loss: 0.0072, val_loss: 0.0267
# Epoch [7/1000], time: 0s, loss: 0.0076, val_loss: 0.0572
# Epoch [8/1000], time: 0s, loss: 0.0084, val_loss: 0.0252
# Model saved to weights/multi2multi/best-MLP.pth
# Epoch [9/1000], time: 0s, loss: 0.0060, val_loss: 0.0209
# Epoch [10/1000], time: 0s, loss: 0.0065, val_loss: 0.0760
# Epoch [11/1000], time: 0s, loss: 0.0154, val_loss: 0.0244
# Epoch [12/1000], time: 0s, loss: 0.0060, val_loss: 0.0234
# Epoch [13/1000], time: 0s, loss: 0.0059, val_loss: 0.0414
# Model saved to weights/multi2multi/best-MLP.pth
# Epoch [14/1000], time: 0s, loss: 0.0068, val_loss: 0.0208
# Epoch [15/1000], time: 0s, loss: 0.0060, val_loss: 0.0324
# Model saved to weights/multi2multi/best-MLP.pth
# Epoch [16/1000], time: 0s, loss: 0.0065, val_loss: 0.0200
# Epoch [17/1000], time: 0s, loss: 0.0060, val_loss: 0.0270
# Epoch [18/1000], time: 0s, loss: 0.0076, val_loss: 0.0203
# Epoch [19/1000], time: 0s, loss: 0.0053, val_loss: 0.0716
# Epoch [20/1000], time: 0s, loss: 0.0094, val_loss: 0.0201
# Epoch [21/1000], time: 0s, loss: 0.0084, val_loss: 0.0276
# Epoch [22/1000], time: 0s, loss: 0.0053, val_loss: 0.0304
# Epoch [23/1000], time: 0s, loss: 0.0055, val_loss: 0.0272
# Epoch [24/1000], time: 0s, loss: 0.0068, val_loss: 0.0227
# Epoch [25/1000], time: 0s, loss: 0.0105, val_loss: 0.0474
# Epoch [26/1000], time: 0s, loss: 0.0063, val_loss: 0.0361
# Epoch [27/1000], time: 0s, loss: 0.0060, val_loss: 0.0312
# Epoch [28/1000], time: 0s, loss: 0.0105, val_loss: 0.0276
# Epoch [29/1000], time: 0s, loss: 0.0046, val_loss: 0.0295
# Epoch [30/1000], time: 0s, loss: 0.0062, val_loss: 0.0240
# Epoch [31/1000], time: 0s, loss: 0.0047, val_loss: 0.0205
# Model saved to weights/multi2multi/best-MLP.pth
# Epoch [32/1000], time: 0s, loss: 0.0070, val_loss: 0.0192
# Epoch [33/1000], time: 0s, loss: 0.0052, val_loss: 0.0215
# Epoch [34/1000], time: 0s, loss: 0.0053, val_loss: 0.0194
# Epoch [35/1000], time: 0s, loss: 0.0046, val_loss: 0.0379
# Epoch [36/1000], time: 0s, loss: 0.0083, val_loss: 0.0230
# Epoch [37/1000], time: 0s, loss: 0.0039, val_loss: 0.0284
# Epoch [38/1000], time: 0s, loss: 0.0053, val_loss: 0.0209
# Epoch [39/1000], time: 0s, loss: 0.0067, val_loss: 0.0206
# Epoch [40/1000], time: 0s, loss: 0.0044, val_loss: 0.0262
# Epoch [41/1000], time: 0s, loss: 0.0054, val_loss: 0.0216
# Epoch [42/1000], time: 0s, loss: 0.0042, val_loss: 0.0326
# Epoch [43/1000], time: 0s, loss: 0.0073, val_loss: 0.0338
# Epoch [44/1000], time: 0s, loss: 0.0055, val_loss: 0.0222
# Model saved to weights/multi2multi/best-MLP.pth
# Epoch [45/1000], time: 0s, loss: 0.0052, val_loss: 0.0181
# Epoch [46/1000], time: 0s, loss: 0.0049, val_loss: 0.0188
# Model saved to weights/multi2multi/best-MLP.pth
# Epoch [47/1000], time: 0s, loss: 0.0054, val_loss: 0.0169
# Epoch [48/1000], time: 0s, loss: 0.0042, val_loss: 0.0314
# Epoch [49/1000], time: 0s, loss: 0.0053, val_loss: 0.0204
# Epoch [50/1000], time: 0s, loss: 0.0037, val_loss: 0.0187
# Epoch [51/1000], time: 0s, loss: 0.0040, val_loss: 0.0255
# Epoch [52/1000], time: 0s, loss: 0.0046, val_loss: 0.0183
# Epoch [53/1000], time: 0s, loss: 0.0036, val_loss: 0.0228
# Epoch [54/1000], time: 0s, loss: 0.0062, val_loss: 0.0189
# Epoch [55/1000], time: 0s, loss: 0.0041, val_loss: 0.0224
# Epoch [56/1000], time: 0s, loss: 0.0041, val_loss: 0.0512
# Epoch [57/1000], time: 0s, loss: 0.0096, val_loss: 0.0559
# Epoch [58/1000], time: 0s, loss: 0.0066, val_loss: 0.0309
# Epoch [59/1000], time: 0s, loss: 0.0054, val_loss: 0.0302
# Epoch [60/1000], time: 0s, loss: 0.0053, val_loss: 0.0232
# Epoch [61/1000], time: 0s, loss: 0.0039, val_loss: 0.0254
# Epoch [62/1000], time: 0s, loss: 0.0040, val_loss: 0.0300
# Epoch [63/1000], time: 0s, loss: 0.0058, val_loss: 0.0223
# Epoch [64/1000], time: 0s, loss: 0.0040, val_loss: 0.0302
# Epoch [65/1000], time: 0s, loss: 0.0048, val_loss: 0.0250
# Epoch [66/1000], time: 0s, loss: 0.0055, val_loss: 0.0276
# Epoch [67/1000], time: 0s, loss: 0.0040, val_loss: 0.0224
# Epoch [68/1000], time: 0s, loss: 0.0044, val_loss: 0.0282
# Epoch [69/1000], time: 0s, loss: 0.0065, val_loss: 0.0197
# Epoch [70/1000], time: 0s, loss: 0.0037, val_loss: 0.0235
# Epoch [71/1000], time: 0s, loss: 0.0039, val_loss: 0.0207
# Epoch [72/1000], time: 0s, loss: 0.0042, val_loss: 0.0243
# Epoch [73/1000], time: 0s, loss: 0.0051, val_loss: 0.0226
# Epoch [74/1000], time: 0s, loss: 0.0040, val_loss: 0.0210
# Epoch [75/1000], time: 0s, loss: 0.0048, val_loss: 0.0310
# Epoch [76/1000], time: 0s, loss: 0.0040, val_loss: 0.0198
# Epoch [77/1000], time: 0s, loss: 0.0046, val_loss: 0.0213
# Epoch [78/1000], time: 0s, loss: 0.0039, val_loss: 0.0251
# Epoch [79/1000], time: 0s, loss: 0.0057, val_loss: 0.0249
# Epoch [80/1000], time: 0s, loss: 0.0061, val_loss: 0.0206
# Epoch [81/1000], time: 0s, loss: 0.0063, val_loss: 0.0176
# Epoch [82/1000], time: 0s, loss: 0.0044, val_loss: 0.0227
# Epoch [83/1000], time: 0s, loss: 0.0035, val_loss: 0.0217
# Model saved to weights/multi2multi/best-MLP.pth
# Epoch [84/1000], time: 0s, loss: 0.0041, val_loss: 0.0168
# Epoch [85/1000], time: 0s, loss: 0.0039, val_loss: 0.0192
# Epoch [86/1000], time: 0s, loss: 0.0038, val_loss: 0.0183
# Epoch [87/1000], time: 0s, loss: 0.0042, val_loss: 0.0241
# Epoch [88/1000], time: 0s, loss: 0.0052, val_loss: 0.0244
# Epoch [89/1000], time: 0s, loss: 0.0039, val_loss: 0.0171
# Epoch [90/1000], time: 0s, loss: 0.0035, val_loss: 0.0267
# Epoch [91/1000], time: 0s, loss: 0.0052, val_loss: 0.0200
# Epoch [92/1000], time: 0s, loss: 0.0033, val_loss: 0.0205
# Epoch [93/1000], time: 0s, loss: 0.0032, val_loss: 0.0190
# Model saved to weights/multi2multi/best-MLP.pth
# Epoch [94/1000], time: 0s, loss: 0.0036, val_loss: 0.0157
# Epoch [95/1000], time: 0s, loss: 0.0033, val_loss: 0.0184
# Epoch [96/1000], time: 0s, loss: 0.0030, val_loss: 0.0268
# Epoch [97/1000], time: 0s, loss: 0.0047, val_loss: 0.0196
# Epoch [98/1000], time: 0s, loss: 0.0035, val_loss: 0.0220
# Epoch [99/1000], time: 0s, loss: 0.0045, val_loss: 0.0190
# Epoch [100/1000], time: 0s, loss: 0.0040, val_loss: 0.0497
# Epoch [101/1000], time: 0s, loss: 0.0109, val_loss: 0.0205
# Epoch [102/1000], time: 0s, loss: 0.0037, val_loss: 0.0220
# Epoch [103/1000], time: 0s, loss: 0.0037, val_loss: 0.0407
# Epoch [104/1000], time: 0s, loss: 0.0084, val_loss: 0.0376
# Epoch [105/1000], time: 0s, loss: 0.0043, val_loss: 0.0198
# Epoch [106/1000], time: 0s, loss: 0.0055, val_loss: 0.0230
# Epoch [107/1000], time: 0s, loss: 0.0040, val_loss: 0.0214
# Epoch [108/1000], time: 0s, loss: 0.0047, val_loss: 0.0194
# Epoch [109/1000], time: 0s, loss: 0.0036, val_loss: 0.0223
# Epoch [110/1000], time: 0s, loss: 0.0049, val_loss: 0.0255
# Epoch [111/1000], time: 0s, loss: 0.0040, val_loss: 0.0267
# Epoch [112/1000], time: 0s, loss: 0.0037, val_loss: 0.0217
# Epoch [113/1000], time: 0s, loss: 0.0046, val_loss: 0.0376
# Epoch [114/1000], time: 0s, loss: 0.0075, val_loss: 0.0217
# Epoch [115/1000], time: 0s, loss: 0.0034, val_loss: 0.0387
# Epoch [116/1000], time: 0s, loss: 0.0055, val_loss: 0.0191
# Epoch [117/1000], time: 0s, loss: 0.0052, val_loss: 0.0369
# Epoch [118/1000], time: 0s, loss: 0.0050, val_loss: 0.0246
# Epoch [119/1000], time: 0s, loss: 0.0036, val_loss: 0.0196
# Epoch [120/1000], time: 0s, loss: 0.0038, val_loss: 0.0205
# Epoch [121/1000], time: 0s, loss: 0.0033, val_loss: 0.0250
# Epoch [122/1000], time: 0s, loss: 0.0041, val_loss: 0.0314
# Epoch [123/1000], time: 0s, loss: 0.0044, val_loss: 0.0197
# Epoch [124/1000], time: 0s, loss: 0.0032, val_loss: 0.0197
# Epoch [125/1000], time: 0s, loss: 0.0037, val_loss: 0.0206
# Epoch [126/1000], time: 0s, loss: 0.0035, val_loss: 0.0198
# Epoch [127/1000], time: 0s, loss: 0.0042, val_loss: 0.0210
# Epoch [128/1000], time: 0s, loss: 0.0038, val_loss: 0.0243
# Epoch [129/1000], time: 0s, loss: 0.0034, val_loss: 0.0281
# Epoch [130/1000], time: 0s, loss: 0.0043, val_loss: 0.0203
# Epoch [131/1000], time: 0s, loss: 0.0033, val_loss: 0.0238
# Epoch [132/1000], time: 0s, loss: 0.0039, val_loss: 0.0206
# Epoch [133/1000], time: 0s, loss: 0.0033, val_loss: 0.0185
# Epoch [134/1000], time: 0s, loss: 0.0032, val_loss: 0.0210
# Epoch [135/1000], time: 0s, loss: 0.0036, val_loss: 0.0182
# Epoch [136/1000], time: 0s, loss: 0.0032, val_loss: 0.0269
# Epoch [137/1000], time: 0s, loss: 0.0040, val_loss: 0.0236
# Epoch [138/1000], time: 0s, loss: 0.0038, val_loss: 0.0261
# Epoch [139/1000], time: 0s, loss: 0.0039, val_loss: 0.0206
# Epoch [140/1000], time: 0s, loss: 0.0034, val_loss: 0.0245
# Epoch [141/1000], time: 0s, loss: 0.0032, val_loss: 0.0195
# Epoch [142/1000], time: 0s, loss: 0.0040, val_loss: 0.0299
# Epoch [143/1000], time: 0s, loss: 0.0034, val_loss: 0.0180
# Epoch [144/1000], time: 0s, loss: 0.0036, val_loss: 0.0204
# Epoch [145/1000], time: 0s, loss: 0.0040, val_loss: 0.0207
# Epoch [146/1000], time: 0s, loss: 0.0031, val_loss: 0.0230
# Epoch [147/1000], time: 0s, loss: 0.0035, val_loss: 0.0207
# Epoch [148/1000], time: 0s, loss: 0.0035, val_loss: 0.0274
# Epoch [149/1000], time: 0s, loss: 0.0040, val_loss: 0.0326
# Epoch [150/1000], time: 0s, loss: 0.0053, val_loss: 0.0191
# Epoch [151/1000], time: 0s, loss: 0.0032, val_loss: 0.0235
# Epoch [152/1000], time: 0s, loss: 0.0036, val_loss: 0.0177
# Epoch [153/1000], time: 0s, loss: 0.0039, val_loss: 0.0208
# Epoch [154/1000], time: 0s, loss: 0.0031, val_loss: 0.0212
# Epoch [155/1000], time: 0s, loss: 0.0035, val_loss: 0.0188
# Epoch [156/1000], time: 0s, loss: 0.0032, val_loss: 0.0220
# Epoch [157/1000], time: 0s, loss: 0.0030, val_loss: 0.0201
# Epoch [158/1000], time: 0s, loss: 0.0031, val_loss: 0.0241
# Epoch [159/1000], time: 0s, loss: 0.0052, val_loss: 0.0206
# Epoch [160/1000], time: 0s, loss: 0.0033, val_loss: 0.0216
# Epoch [161/1000], time: 0s, loss: 0.0036, val_loss: 0.0216
# Epoch [162/1000], time: 0s, loss: 0.0032, val_loss: 0.0179
# Epoch [163/1000], time: 0s, loss: 0.0049, val_loss: 0.0177
# Epoch [164/1000], time: 0s, loss: 0.0037, val_loss: 0.0169
# Epoch [165/1000], time: 0s, loss: 0.0035, val_loss: 0.0201
# Epoch [166/1000], time: 0s, loss: 0.0034, val_loss: 0.0297
# Epoch [167/1000], time: 0s, loss: 0.0043, val_loss: 0.0494
# Epoch [168/1000], time: 0s, loss: 0.0070, val_loss: 0.0194
# Epoch [169/1000], time: 0s, loss: 0.0036, val_loss: 0.0181
# Epoch [170/1000], time: 0s, loss: 0.0033, val_loss: 0.0194
# Epoch [171/1000], time: 0s, loss: 0.0046, val_loss: 0.0221
# Epoch [172/1000], time: 0s, loss: 0.0055, val_loss: 0.0193
# Epoch [173/1000], time: 0s, loss: 0.0029, val_loss: 0.0176
# Epoch [174/1000], time: 0s, loss: 0.0037, val_loss: 0.0187
# Epoch [175/1000], time: 0s, loss: 0.0035, val_loss: 0.0186
# Epoch [176/1000], time: 0s, loss: 0.0030, val_loss: 0.0238
# Epoch [177/1000], time: 0s, loss: 0.0033, val_loss: 0.0303
# Epoch [178/1000], time: 0s, loss: 0.0041, val_loss: 0.0170
# Epoch [179/1000], time: 0s, loss: 0.0042, val_loss: 0.0197
# Epoch [180/1000], time: 0s, loss: 0.0034, val_loss: 0.0240
# Epoch [181/1000], time: 0s, loss: 0.0053, val_loss: 0.0165
# Epoch [182/1000], time: 0s, loss: 0.0041, val_loss: 0.0199
# Epoch [183/1000], time: 0s, loss: 0.0054, val_loss: 0.0184
# Epoch [184/1000], time: 0s, loss: 0.0035, val_loss: 0.0174
# Epoch [185/1000], time: 0s, loss: 0.0030, val_loss: 0.0176
# Epoch [186/1000], time: 0s, loss: 0.0034, val_loss: 0.0182
# Epoch [187/1000], time: 0s, loss: 0.0044, val_loss: 0.0173
# Epoch [188/1000], time: 0s, loss: 0.0039, val_loss: 0.0250
# Epoch [189/1000], time: 0s, loss: 0.0039, val_loss: 0.0277
# Epoch [190/1000], time: 0s, loss: 0.0032, val_loss: 0.0186
# Epoch [191/1000], time: 0s, loss: 0.0030, val_loss: 0.0392
# Epoch [192/1000], time: 0s, loss: 0.0049, val_loss: 0.0181
# Epoch [193/1000], time: 0s, loss: 0.0039, val_loss: 0.0206
# Early stopping at epoch 194
# {'Name': 'MLP', 'Type': 'multi2multi', 'MAE': 0.014595421589910984}

# %%
MLP_multi2multi_manager.plot(y=multi2multi_loader.y_test,
                             yhat=MLP_multi2multi_manager.predict(multi2multi_loader.test_loader),
                             feature_names=multi2multi_loader.out_features,
                             save_dir=os.path.join(plot_dir, sub_dir),
                             save_plots=True,
                             num_elements=ele)

# %%
class LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers, ahead):
        super(LSTM, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.ahead = ahead
        self.output_size = output_size

        # LSTM Layer
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)

        # Output layer
        self.fc = nn.Linear(hidden_size, output_size * ahead)

    def forward(self, x):
        # Initialize hidden and cell states
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)

        # Forward propagate LSTM
        out, _ = self.lstm(x, (h0, c0))

        # Get the last time step's output for each sequence
        out = out[:, -1, :]

        # Pass through the linear layer and reshape
        out = self.fc(out).view(-1, self.ahead, self.output_size)
        return out

# %%
LSTM_multi2multi = LSTM(input_size=multi2multi_loader.in_variable,
                        hidden_size=hidden_size,
                        output_size=multi2multi_loader.out_variable,
                        ahead=label_size,
                        num_layers=num_layers)
LSTM_multi2multi_manager = ModelManager(model=LSTM_multi2multi,
                                        train_loader=multi2multi_loader.train_loader,
                                        val_loader=multi2multi_loader.val_loader,
                                        lr=learning_rate,
                                        patience=patience)
LSTM_multi2multi_manager.train(num_epochs=num_epochs,
                              save_dir=os.path.join(weight_dir, sub_dir))
results.append({
    "Name": LSTM_multi2multi_manager.model.__class__.__name__,
    "Type": sub_dir,
    "MAE": LSTM_multi2multi_manager.evaluate(loader=multi2multi_loader.test_loader)
})
results[-1]
# Out:
# Model saved to weights/multi2multi/best-LSTM.pth
# Epoch [1/1000], time: 2s, loss: 0.0796, val_loss: 0.0849
# Model saved to weights/multi2multi/best-LSTM.pth
# Epoch [2/1000], time: 3s, loss: 0.0120, val_loss: 0.0361
# Model saved to weights/multi2multi/best-LSTM.pth
# Epoch [3/1000], time: 1s, loss: 0.0080, val_loss: 0.0171
# Epoch [4/1000], time: 1s, loss: 0.0069, val_loss: 0.0287
# Epoch [5/1000], time: 1s, loss: 0.0057, val_loss: 0.0254
# Epoch [6/1000], time: 1s, loss: 0.0054, val_loss: 0.0324
# Epoch [7/1000], time: 1s, loss: 0.0061, val_loss: 0.0188
# Epoch [8/1000], time: 1s, loss: 0.0057, val_loss: 0.0231
# Model saved to weights/multi2multi/best-LSTM.pth
# Epoch [9/1000], time: 1s, loss: 0.0054, val_loss: 0.0167
# Epoch [10/1000], time: 1s, loss: 0.0052, val_loss: 0.0201
# Epoch [11/1000], time: 1s, loss: 0.0048, val_loss: 0.0309
# Epoch [12/1000], time: 1s, loss: 0.0056, val_loss: 0.0291
# Model saved to weights/multi2multi/best-LSTM.pth
# Epoch [13/1000], time: 1s, loss: 0.0048, val_loss: 0.0153
# Epoch [14/1000], time: 1s, loss: 0.0047, val_loss: 0.0265
# Epoch [15/1000], time: 1s, loss: 0.0038, val_loss: 0.0376
# Model saved to weights/multi2multi/best-LSTM.pth
# Epoch [16/1000], time: 1s, loss: 0.0045, val_loss: 0.0128
# Model saved to weights/multi2multi/best-LSTM.pth
# Epoch [17/1000], time: 1s, loss: 0.0037, val_loss: 0.0117
# Epoch [18/1000], time: 1s, loss: 0.0042, val_loss: 0.0147
# Epoch [19/1000], time: 1s, loss: 0.0040, val_loss: 0.0158
# Epoch [20/1000], time: 1s, loss: 0.0045, val_loss: 0.0169
# Epoch [21/1000], time: 1s, loss: 0.0041, val_loss: 0.0343
# Epoch [22/1000], time: 0s, loss: 0.0045, val_loss: 0.0260
# Epoch [23/1000], time: 1s, loss: 0.0036, val_loss: 0.0251
# Epoch [24/1000], time: 1s, loss: 0.0060, val_loss: 0.0131
# Epoch [25/1000], time: 1s, loss: 0.0036, val_loss: 0.0225
# Epoch [26/1000], time: 1s, loss: 0.0044, val_loss: 0.0174
# Epoch [27/1000], time: 1s, loss: 0.0036, val_loss: 0.0170
# Epoch [28/1000], time: 1s, loss: 0.0040, val_loss: 0.0381
# Epoch [29/1000], time: 1s, loss: 0.0037, val_loss: 0.0176
# Epoch [30/1000], time: 1s, loss: 0.0040, val_loss: 0.0151
# Epoch [31/1000], time: 1s, loss: 0.0039, val_loss: 0.0124
# Epoch [32/1000], time: 1s, loss: 0.0031, val_loss: 0.0947
# Epoch [33/1000], time: 1s, loss: 0.0135, val_loss: 0.0314
# Epoch [34/1000], time: 1s, loss: 0.0033, val_loss: 0.0139
# Epoch [35/1000], time: 1s, loss: 0.0031, val_loss: 0.0118
# Epoch [36/1000], time: 1s, loss: 0.0029, val_loss: 0.0124
# Model saved to weights/multi2multi/best-LSTM.pth
# Epoch [37/1000], time: 1s, loss: 0.0033, val_loss: 0.0109
# Epoch [38/1000], time: 1s, loss: 0.0031, val_loss: 0.0230
# Epoch [39/1000], time: 1s, loss: 0.0054, val_loss: 0.0272
# Epoch [40/1000], time: 1s, loss: 0.0038, val_loss: 0.0112
# Epoch [41/1000], time: 1s, loss: 0.0040, val_loss: 0.0122
# Epoch [42/1000], time: 1s, loss: 0.0032, val_loss: 0.0121
# Epoch [43/1000], time: 1s, loss: 0.0029, val_loss: 0.0114
# Epoch [44/1000], time: 1s, loss: 0.0038, val_loss: 0.0227
# Epoch [45/1000], time: 1s, loss: 0.0040, val_loss: 0.0135
# Epoch [46/1000], time: 1s, loss: 0.0032, val_loss: 0.0207
# Epoch [47/1000], time: 1s, loss: 0.0032, val_loss: 0.0214
# Epoch [48/1000], time: 1s, loss: 0.0031, val_loss: 0.0301
# Epoch [49/1000], time: 1s, loss: 0.0035, val_loss: 0.0142
# Epoch [50/1000], time: 1s, loss: 0.0028, val_loss: 0.0162
# Epoch [51/1000], time: 1s, loss: 0.0048, val_loss: 0.0117
# Epoch [52/1000], time: 1s, loss: 0.0031, val_loss: 0.0146
# Epoch [53/1000], time: 1s, loss: 0.0039, val_loss: 0.0127
# Epoch [54/1000], time: 1s, loss: 0.0028, val_loss: 0.0210
# Epoch [55/1000], time: 1s, loss: 0.0037, val_loss: 0.0116
# Epoch [56/1000], time: 1s, loss: 0.0031, val_loss: 0.0117
# Epoch [57/1000], time: 1s, loss: 0.0027, val_loss: 0.0151
# Epoch [58/1000], time: 1s, loss: 0.0029, val_loss: 0.0120
# Epoch [59/1000], time: 1s, loss: 0.0029, val_loss: 0.0116
# Epoch [60/1000], time: 1s, loss: 0.0033, val_loss: 0.0116
# Epoch [61/1000], time: 1s, loss: 0.0037, val_loss: 0.0115
# Epoch [62/1000], time: 1s, loss: 0.0036, val_loss: 0.0125
# Epoch [63/1000], time: 1s, loss: 0.0032, val_loss: 0.0188
# Epoch [64/1000], time: 1s, loss: 0.0039, val_loss: 0.0393
# Epoch [65/1000], time: 1s, loss: 0.0043, val_loss: 0.0120
# Epoch [66/1000], time: 1s, loss: 0.0029, val_loss: 0.0146
# Epoch [67/1000], time: 1s, loss: 0.0038, val_loss: 0.0112
# Epoch [68/1000], time: 1s, loss: 0.0033, val_loss: 0.0461
# Epoch [69/1000], time: 1s, loss: 0.0077, val_loss: 0.0279
# Epoch [70/1000], time: 1s, loss: 0.0038, val_loss: 0.0204
# Epoch [71/1000], time: 1s, loss: 0.0036, val_loss: 0.0151
# Epoch [72/1000], time: 1s, loss: 0.0033, val_loss: 0.0243
# Epoch [73/1000], time: 1s, loss: 0.0030, val_loss: 0.0121
# Epoch [74/1000], time: 1s, loss: 0.0028, val_loss: 0.0131
# Model saved to weights/multi2multi/best-LSTM.pth
# Epoch [75/1000], time: 1s, loss: 0.0030, val_loss: 0.0101
# Epoch [76/1000], time: 1s, loss: 0.0026, val_loss: 0.0155
# Epoch [77/1000], time: 1s, loss: 0.0029, val_loss: 0.0115
# Epoch [78/1000], time: 0s, loss: 0.0027, val_loss: 0.0119
# Epoch [79/1000], time: 0s, loss: 0.0036, val_loss: 0.0138
# Epoch [80/1000], time: 1s, loss: 0.0026, val_loss: 0.0152
# Epoch [81/1000], time: 1s, loss: 0.0028, val_loss: 0.0126
# Epoch [82/1000], time: 0s, loss: 0.0028, val_loss: 0.0123
# Epoch [83/1000], time: 1s, loss: 0.0027, val_loss: 0.0153
# Epoch [84/1000], time: 1s, loss: 0.0028, val_loss: 0.0115
# Epoch [85/1000], time: 1s, loss: 0.0027, val_loss: 0.0105
# Epoch [86/1000], time: 1s, loss: 0.0026, val_loss: 0.0146
# Epoch [87/1000], time: 1s, loss: 0.0027, val_loss: 0.0159
# Epoch [88/1000], time: 1s, loss: 0.0032, val_loss: 0.0114
# Epoch [89/1000], time: 1s, loss: 0.0028, val_loss: 0.0617
# Epoch [90/1000], time: 1s, loss: 0.0106, val_loss: 0.0222
# Epoch [91/1000], time: 1s, loss: 0.0029, val_loss: 0.0129
# Epoch [92/1000], time: 1s, loss: 0.0029, val_loss: 0.0127
# Epoch [93/1000], time: 1s, loss: 0.0029, val_loss: 0.0465
# Epoch [94/1000], time: 0s, loss: 0.0071, val_loss: 0.0221
# Epoch [95/1000], time: 1s, loss: 0.0034, val_loss: 0.0143
# Epoch [96/1000], time: 1s, loss: 0.0029, val_loss: 0.0126
# Epoch [97/1000], time: 1s, loss: 0.0028, val_loss: 0.0141
# Epoch [98/1000], time: 0s, loss: 0.0028, val_loss: 0.0356
# Model saved to weights/multi2multi/best-LSTM.pth
# Epoch [99/1000], time: 1s, loss: 0.0053, val_loss: 0.0100
# Epoch [100/1000], time: 1s, loss: 0.0030, val_loss: 0.0198
# Epoch [101/1000], time: 1s, loss: 0.0049, val_loss: 0.0364
# Epoch [102/1000], time: 1s, loss: 0.0050, val_loss: 0.0499
# Epoch [103/1000], time: 1s, loss: 0.0081, val_loss: 0.0125
# Epoch [104/1000], time: 1s, loss: 0.0027, val_loss: 0.0150
# Epoch [105/1000], time: 1s, loss: 0.0029, val_loss: 0.0109
# Epoch [106/1000], time: 1s, loss: 0.0034, val_loss: 0.0124
# Epoch [107/1000], time: 1s, loss: 0.0033, val_loss: 0.0139
# Epoch [108/1000], time: 1s, loss: 0.0037, val_loss: 0.0131
# Epoch [109/1000], time: 1s, loss: 0.0031, val_loss: 0.0183
# Epoch [110/1000], time: 1s, loss: 0.0031, val_loss: 0.0252
# Epoch [111/1000], time: 1s, loss: 0.0033, val_loss: 0.0185
# Epoch [112/1000], time: 1s, loss: 0.0040, val_loss: 0.0199
# Epoch [113/1000], time: 1s, loss: 0.0037, val_loss: 0.0132
# Epoch [114/1000], time: 1s, loss: 0.0026, val_loss: 0.0153
# Epoch [115/1000], time: 1s, loss: 0.0030, val_loss: 0.0130
# Epoch [116/1000], time: 1s, loss: 0.0025, val_loss: 0.0118
# Epoch [117/1000], time: 1s, loss: 0.0030, val_loss: 0.0177
# Epoch [118/1000], time: 1s, loss: 0.0037, val_loss: 0.0155
# Epoch [119/1000], time: 1s, loss: 0.0027, val_loss: 0.0111
# Epoch [120/1000], time: 1s, loss: 0.0027, val_loss: 0.0169
# Epoch [121/1000], time: 1s, loss: 0.0027, val_loss: 0.0146
# Epoch [122/1000], time: 1s, loss: 0.0028, val_loss: 0.0124
# Epoch [123/1000], time: 1s, loss: 0.0030, val_loss: 0.0102
# Epoch [124/1000], time: 1s, loss: 0.0027, val_loss: 0.0129
# Epoch [125/1000], time: 1s, loss: 0.0035, val_loss: 0.0117
# Epoch [126/1000], time: 1s, loss: 0.0027, val_loss: 0.0121
# Epoch [127/1000], time: 1s, loss: 0.0027, val_loss: 0.0396
# Epoch [128/1000], time: 1s, loss: 0.0057, val_loss: 0.0242
# Epoch [129/1000], time: 1s, loss: 0.0029, val_loss: 0.0135
# Epoch [130/1000], time: 1s, loss: 0.0035, val_loss: 0.0185
# Epoch [131/1000], time: 1s, loss: 0.0036, val_loss: 0.0125
# Epoch [132/1000], time: 1s, loss: 0.0029, val_loss: 0.0135
# Epoch [133/1000], time: 1s, loss: 0.0026, val_loss: 0.0122
# Epoch [134/1000], time: 1s, loss: 0.0037, val_loss: 0.0239
# Epoch [135/1000], time: 1s, loss: 0.0035, val_loss: 0.0171
# Epoch [136/1000], time: 1s, loss: 0.0032, val_loss: 0.0173
# Epoch [137/1000], time: 1s, loss: 0.0030, val_loss: 0.0111
# Epoch [138/1000], time: 1s, loss: 0.0035, val_loss: 0.0121
# Epoch [139/1000], time: 1s, loss: 0.0028, val_loss: 0.0137

# %%
LSTM_multi2multi_manager.plot(y=multi2multi_loader.y_test,
                              yhat=LSTM_multi2multi_manager.predict(multi2multi_loader.test_loader),
                              feature_names=multi2multi_loader.out_features,
                              save_dir=os.path.join(plot_dir, sub_dir),
                              save_plots=True,
                              num_elements=ele)

# %%
class BiLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers, ahead):
        super(BiLSTM, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.ahead = ahead
        self.output_size = output_size

        # BiLSTM Layer
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, bidirectional=True)

        # Output layer
        # Output size is doubled because BiLSTM has two hidden states for each layer
        self.fc = nn.Linear(hidden_size * 2, output_size * ahead)

    def forward(self, x):
        # Initialize hidden and cell states
        h0 = torch.zeros(self.num_layers * 2, x.size(0), self.hidden_size).to(x.device)  # 2 for bidirection
        c0 = torch.zeros(self.num_layers * 2, x.size(0), self.hidden_size).to(x.device)

        # Forward propagate BiLSTM
        out, _ = self.lstm(x, (h0, c0))

        # Get the last time step's output for each sequence
        out = out[:, -1, :]

        # Pass through the linear layer and reshape
        out = self.fc(out).view(-1, self.ahead, self.output_size)
        return out

# %%
BiLSTM_multi2multi = BiLSTM(input_size=multi2multi_loader.in_variable,
                            hidden_size=hidden_size,
                            output_size=multi2multi_loader.out_variable,
                            ahead=label_size,
                            num_layers=num_layers)
BiLSTM_multi2multi_manager = ModelManager(model=BiLSTM_multi2multi,
                                          train_loader=multi2multi_loader.train_loader,
                                          val_loader=multi2multi_loader.val_loader,
                                          lr=learning_rate,
                                          patience=patience)
BiLSTM_multi2multi_manager.train(num_epochs=num_epochs,
                                 save_dir=os.path.join(weight_dir, sub_dir))
results.append({
    "Name": BiLSTM_multi2multi_manager.model.__class__.__name__,
    "Type": sub_dir,
    "MAE": BiLSTM_multi2multi_manager.evaluate(loader=multi2multi_loader.test_loader)
})
results[-1]

# %%
BiLSTM_multi2multi_manager.plot(y=multi2multi_loader.y_test,
                                yhat=BiLSTM_multi2multi_manager.predict(multi2multi_loader.test_loader),
                                feature_names=multi2multi_loader.out_features,
                                save_dir=os.path.join(plot_dir, sub_dir),
                                save_plots=True,
                                num_elements=ele)

# %%
def inference(y, yhat, df):
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaler.fit(df['close'].values.reshape(-1, 1))

    y_inverse = scaler.inverse_transform(y.reshape(-1, 1))
    yhat_inverse = scaler.inverse_transform(yhat.reshape(-1, 1))

    d_inverse = pd.DataFrame({'Time': df['time'].tail(259).values,
                              'Actual': y_inverse.flatten(),
                              'Predicted': yhat_inverse.flatten()})

    return d_inverse

# %%
yhat=BiLSTM_multi2multi_manager.predict(multi2multi_loader.test_loader)
inference(yhat)
