# %%
# !pip install -U vnstock

# %%
from vnstock import *

# %%
fpt_stock = stock_historical_data(symbol="FPT", start_date="2000-01-01", end_date="2023-12-15", resolution="1D", type="stock", beautify=True, decor=False, source='DNSE')

# %%
fpt_stock[:5]
# Out:
#          time  open  high   low  close  volume ticker
# 0  2012-03-20  6950  6950  6900   6900   94310    FPT
# 1  2012-03-21  6900  6950  6840   6900  145260    FPT
# 2  2012-03-22  6900  6900  6780   6780   90050    FPT
# 3  2012-03-23  6840  6840  6780   6840   71320    FPT
# 4  2012-03-26  6840  6840  6780   6840  112360    FPT

# %%
import pandas as pd

# %%
fpt_stock.to_csv("/content/drive/MyDrive/Thesis/fpt_stock.csv", index=False)

# %%
df = pd.read_csv("/content/drive/MyDrive/Thesis/fpt_stock.csv")
df
# Out:
#             time   open   high    low  close   volume ticker
# 0     2012-03-20   6950   6950   6900   6900    94310    FPT
# 1     2012-03-21   6900   6950   6840   6900   145260    FPT
# 2     2012-03-22   6900   6900   6780   6780    90050    FPT
# 3     2012-03-23   6840   6840   6780   6840    71320    FPT
# 4     2012-03-26   6840   6840   6780   6840   112360    FPT
# ...          ...    ...    ...    ...    ...      ...    ...
# 2930  2023-12-11  95500  95700  94600  95000  1564500    FPT
# 2931  2023-12-12  95400  96800  95300  96800  4084900    FPT
# 2932  2023-12-13  97400  97400  95200  95200  2148100    FPT
# 2933  2023-12-14  95800  96400  95200  96200  1712300    FPT
# 2934  2023-12-15  96200  96300  95000  96200  1474300    FPT
#
# [2935 rows x 7 columns]
